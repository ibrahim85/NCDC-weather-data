# %% [markdown]
# <font color= 'blue'> Importing modules </font>

# %%
import os,sys,re,pickle, sklearn, numpy, re, base64, zlib
import pandas as pd

# %%
home_dir='/home/ubuntu/UCSD_BigData'
sys.path.append(home_dir+'/utils')

from find_waiting_flow import *
from AWS_keypair_management import *

data_dir=home_dir+'/data/weather'
cur_dir =home_dir+'/notebooks/weather_analyis'
# !ls $data_dir
# Out:
# ALL.head.csv	  ghcnd-stations_buffered.txt  SAMPLE_TMAX.csv
# data-source.txt   ghcnd-stations.txt	       SAMPLE_TMAX.csv.old.gz
# ghcnd-readme.txt  ghcnd-version.txt

# %%
Creds= pickle.load(open('/home/ubuntu/Vault/Creds.pkl','rb'))
pair=Creds['mrjob']
key_id=pair['key_id']
secret_key=pair['secret_key']
ID=pair['ID']

# %cd $home_dir/utils/
# !python Make.mrjob.conf.py  #If EC2_VAULT is not defined, default location - '/home/ubuntu/Vault'
# %cd $home_dir/notebooks/weather_analysis
# Out:
# /home/ubuntu/UCSD_BigData/utils
# Created the configuration file: /home/ubuntu/.mrjob.conf
# /home/ubuntu/UCSD_BigData/notebooks/weather_analysis

# %%
f = open('partition_tree.pkl', 'rb') 
(Data_Stations, valid_years, group_neighbours, group2id) = pickle.load(f) 
f.close() 

num_stations = Data_Stations.shape[0]
stations = np.array(Data_Stations.index)
lons = np.array(Data_Stations.ix[:,'longitude'])
lats = np.array(Data_Stations.ix[:,'latitude'])

# %% [markdown]
# ### Collect required data for all the leaves

# %%
# %%writefile Get_Data.py

#!/usr/bin/python
"""
collect the data for each group.
"""
import re,pickle,base64,zlib
from sys import stderr
import sys
import numpy as np

sys.path.append('/usr/lib/python2.6/dist-packages') # a hack because anaconda made mrjob unreachable
from mrjob.job import MRJob
from mrjob.protocol import *

import traceback
from functools import wraps
from sys import stderr

"""this decorator is intended for decorating a function, not a
generator.  Therefore to use it in the context of mrjob, the generator
should call a function that handles a single input records, and that
function should be decorated.

The reason is that if a generator throws an exception it exits and
cannot process any more records.

"""


import pandas,sys

def ECatch(func):
    f_name=func.__name__
    #@wraps(func) cd
    def inner(self,*args,**kwargs):
        try:
            self.increment_counter(self.__class__.__name__,'total in '+f_name,1)
            return func(self,*args,**kwargs)
        except Exception as e:
            self.increment_counter(self.__class__.__name__,'errors in '+f_name,1)
            stderr.write('Error:')
            stderr.write(str(e))
            traceback.print_exc(file=stderr)
            stderr.write('Arguments were %s, %s\n'%(args,kwargs))
            pass
    return inner        

"""
Functions for encoding and decoding arbitrary object into ascii 
so that they can be passed through the hadoop streaming interface.
"""
def loads(eVal):
    """ Decode a string into a value """
    return pickle.loads(zlib.decompress(base64.b64decode(eVal)))

def dumps(Value):
    """ Encode a value as a string """
    return base64.b64encode(zlib.compress(pickle.dumps(Value),9))

class Get_Data(MRJob):
    
    #This adds options --stations for the location of where to get the lookup file
    def configure_options(self):
        super(Get_Data,self).configure_options()
        self.add_file_option('--group_data')
        
    #This loads the lookup file into a field on the object
    def load_group_data(self):
        f = open(self.options.group_data, "rb" )
        (self.Data_Stations, self.valid_years, _ , self.group2id) = pickle.load(f) 
        f.close()
               
    @ECatch
    def map_one(self,line):
        return line.split(',')
    def mapper_get_station_data(self, _, line):
        self.increment_counter('MrJob Counters','mapper',1)
        elements=self.map_one(line)
        [stn , meas, yr] =  elements[0:3]
        if ((stn != 'station') and stn in self.Data_Stations.index and (meas in ['TMIN', 'TMAX']) \
                                                            and (int(yr) in self.valid_years[stn])):
            yield(stn, elements[1:])
   
    
    @ECatch
    def reducer_get_station_data(self, stn, vector):
        D = np.zeros((len(self.valid_years[stn]), 365*2))
        for vec in vector:
            (meas,yr) = vec[0] , int(vec[1])
            
            mat = np.zeros(365*2)
            mat_id = 365*(meas=='TMIN')
            mat[0+mat_id: 365+mat_id] = np.array([(np.nan if j == '' else int(j)) for j in vec[2:]])
            
            D[self.valid_years[stn].index(yr),:] = D[self.valid_years[stn].index(yr),:] + mat
        
        grp_id = self.group2id[self.Data_Stations['group_id'][stn]]
        yield(grp_id, D.tolist())
                         
    def reducer_get_group_data(self, grp_id, mat_list):
        grp_data = []
        for mat in mat_list:
            grp_data = grp_data + mat
            
        yield(grp_id, dumps(np.array(grp_data)))
    
    def steps(self):
        return [
            self.mr(mapper_pre_filter='grep "TMAX\|TMIN"',
                    mapper_init = self.load_group_data,
                    mapper=self.mapper_get_station_data,
                    reducer_init = self.load_group_data,
                    reducer=self.reducer_get_station_data),
            self.mr(reducer=self.reducer_get_group_data)
        ]
if __name__ == '__main__':
    Get_Data.run()
# Out:
# Overwriting Get_Data.py

# %%
#Running on local data
# !python Get_Data.py -r local --group_data ./partition_tree.pkl  $data_dir/ALL.head.csv  > Data_local
# Out:
# using configs in /home/ubuntu/.mrjob.conf
# creating tmp directory /tmp/Get_Data.ubuntu.20140527.085423.772000
# writing to /tmp/Get_Data.ubuntu.20140527.085423.772000/step-0-mapper_part-00000
# > cat /tmp/Get_Data.ubuntu.20140527.085423.772000/input_part-00000 | grep 'TMAX\|TMIN' | /home/ubuntu/anaconda/bin/python Get_Data.py --step-num=0 --mapper --group_data partition_tree.pkl > /tmp/Get_Data.ubuntu.20140527.085423.772000/step-0-mapper_part-00000
# writing to /tmp/Get_Data.ubuntu.20140527.085423.772000/step-0-mapper_part-00001
# > cat /tmp/Get_Data.ubuntu.20140527.085423.772000/input_part-00001 | grep 'TMAX\|TMIN' | /home/ubuntu/anaconda/bin/python Get_Data.py --step-num=0 --mapper --group_data partition_tree.pkl > /tmp/Get_Data.ubuntu.20140527.085423.772000/step-0-mapper_part-00001
# Counters from step 1:
#   Get_Data:
#     total in map_one: 229
#   MrJob Counters:
#     mapper: 229
# writing to /tmp/Get_Data.ubuntu.20140527.085423.772000/step-0-mapper-sorted
# > sort /tmp/Get_Data.ubuntu.20140527.085423.772000/step-0-mapper_part-00000 /tmp/Get_Data.ubuntu.20140527.085423.772000/step-0-mapper_part-00001
# writing to /tmp/Get_Data.ubuntu.20140527.085423.772000/step-0-reducer_part-00000
# > /home/ubuntu/anaconda/bin/python Get_Data.py --step-num=0 --reducer --group_data partition_tree.pkl /tmp/Get_Data.ubuntu.20140527.085423.772000/input_part-00000 > /tmp/Get_Data.ubuntu.20140527.085423.772000/step-0-reducer_part-00000
# writing to /tmp/Get_Data.ubuntu.20140527.085423.772000/step-0-reducer_part-00001
# > /home/ubuntu/anaconda/bin/python Get_Data.py --step-num=0 --reducer --group_data partition_tree.pkl /tmp/Get_Data.ubuntu.20140527.085423.772000/input_part-00001 > /tmp/Get_Data.ubuntu.20140527.085423.772000/step-0-reducer_part-00001
# Counters from step 1:
#   Get_Data:
#     total in map_one: 229
#     total in reducer_get_station_data: 4
#   MrJob Counters:
#     mapper: 229
# writing to /tmp/Get_Data.ubuntu.20140527.085423.772000/step-1-mapper_part-00000
# > cat /tmp/Get_Data.ubuntu.20140527.085423.772000/input_part-00000 | cat > /tmp/Get_Data.ubuntu.20140527.085423.772000/step-1-mapper_part-00000
# writing to /tmp/Get_Data.ubuntu.20140527.085423.772000/step-1-mapper_part-00001
# > cat /tmp/Get_Data.ubuntu.20140527.085423.772000/input_part-00001 | cat > /tmp/Get_Data.ubuntu.20140527.085423.772000/step-1-mapper_part-00001
# Counters from step 2:
#   (no counters found)
# writing to /tmp/Get_Data.ubuntu.20140527.085423.772000/step-1-mapper-sorted
# > sort /tmp/Get_Data.ubuntu.20140527.085423.772000/step-1-mapper_part-00000 /tmp/Get_Data.ubuntu.20140527.085423.772000/step-1-mapper_part-00001
# writing to /tmp/Get_Data.ubuntu.20140527.085423.772000/step-1-reducer_part-00000
# > /home/ubuntu/anaconda/bin/python Get_Data.py --step-num=1 --reducer --group_data partition_tree.pkl /tmp/Get_Data.ubuntu.20140527.085423.772000/input_part-00000 > /tmp/Get_Data.ubuntu.20140527.085423.772000/step-1-reducer_part-00000
# writing to /tmp/Get_Data.ubuntu.20140527.085423.772000/step-1-reducer_part-00001
# > /home/ubuntu/anaconda/bin/python Get_Data.py --step-num=1 --reducer --group_data partition_tree.pkl /tmp/Get_Data.ubuntu.20140527.085423.772000/input_part-00001 > /tmp/Get_Data.ubuntu.20140527.085423.772000/step-1-reducer_part-00001
# Counters from step 2:
#   (no counters found)
# Moving /tmp/Get_Data.ubuntu.20140527.085423.772000/step-1-reducer_part-00000 -> /tmp/Get_Data.ubuntu.20140527.085423.772000/output/part-00000
# Moving /tmp/Get_Data.ubuntu.20140527.085423.772000/step-1-reducer_part-00001 -> /tmp/Get_Data.ubuntu.20140527.085423.772000/output/part-00001
# Streaming final output from /tmp/Get_Data.ubuntu.20140527.085423.772000/output
# removing tmp directory /tmp/Get_Data.ubuntu.20140527.085423.772000

# %%
#job_flow_id=find_waiting_flow(key_id,secret_key)
# !python Get_Data.py -r emr --emr-job-flow-id j-LTOJMJ14G840 --group_data ./partition_tree.pkl  hdfs:/weather/weather.csv > Data

# %% [markdown]
# ### Computing Covariance for each group

# %%
# %%writefile Compute_Cov.py

#!/usr/bin/python
import cPickle as pickle
from StringIO import StringIO
import numpy as np
from mrjob.job import MRJob
from mrjob.protocol import PickleValueProtocol
from sys import stderr

class Compute_Cov(MRJob):
    INTERNAL_PROTOCOL = PickleValueProtocol
    def compute_outer_products(self, _, line):
        self.increment_counter('MrJob Counters','mapper',1)
        xi = np.genfromtxt(StringIO(line),delimiter=",")
        cov = np.outer(xi, xi) 
        yield(None,cov)
    
    def sum_outer_products(self, key, cov_list):
        self.increment_counter('MrJob Counters','reducer',1)
        final_cov = np.zeros((365*2, 365*2))
        for cov in cov_list:
            final_cov = final_cov + cov
            stderr.write('hello')
        yield(None,final_cov)
    
    def steps(self):
        return [
            self.mr(mapper=self.compute_outer_products,
                    combiner = self.sum_outer_products,
                    reducer=self.sum_outer_products)
        ]
    
if __name__ == '__main__':
    Compute_Cov.run()

# %%
from sklearn.preprocessing import Imputer
def loads(eVal):
    """ Decode a string into a value """
    return pickle.loads(zlib.decompress(base64.b64decode(eVal)))

f = open('Data_store')
mean_dict = {}
mat = []
imp = Imputer(missing_values='NaN', strategy='mean', axis=1)
for i in f:
    grp , dum = i.split()
    print grp
    mat =  loads(dum[1:-1])
    imp.fit(mat)
    mat2 = imp.transform(mat)
    print shape(mat2)
    a = numpy.cov(mat2)
    print a
    break
# Out:
# 1
# (1674, 730)
# [[ 18280.51370027  13604.06243715  14067.21350023 ...,  14326.52903681
#    14020.58947295  15165.09997505]
#  [ 13604.06243715  14516.77476603  12615.13041253 ...,  12826.4122811
#    12160.16713399  13527.74531231]
#  [ 14067.21350023  12615.13041253  15510.40675724 ...,  12913.05634695
#    13114.30888405  13833.87597559]
#  ...,
#  [ 14326.52903681  12826.4122811   12913.05634695 ...,  16052.62933226
#    13350.98040156  14200.87715575]
#  [ 14020.58947295  12160.16713399  13114.30888405 ...,  13350.98040156
#    15426.2737125   14101.3156584 ]
#  [ 15165.09997505  13527.74531231  13833.87597559 ...,  14200.87715575
#    14101.3156584   17482.61538054]]

# %%
# !s3cmd put partition_tree.pkl s3://guy_fawkes.bucket
# Out:
# partition_tree.pkl -> s3://guy_fawkes.bucket/partition_tree.pkl  [1 of 1]
#    290816 of 35766222     0% in    0s    10.81 MB/s
#   1585152 of 35766222     4% in    0s    19.49 MB/s
#   2826240 of 35766222     7% in    0s    20.88 MB/s
#   4161536 of 35766222    11% in    0s    22.03 MB/s
#   5419008 of 35766222    15% in    0s    22.33 MB/s
#   6766592 of 35766222    18% in    0s    22.82 MB/s
#   7974912 of 35766222    22% in    0s    22.77 MB/s
#   9302016 of 35766222    26% in    0s    23.02 MB/s
#  10522624 of 35766222    29% in    0s    22.98 MB/s
#  11735040 of 35766222    32% in    0s    22.93 MB/s
#  13000704 of 35766222    36% in    0s    23.01 MB/s
#  14196736 of 35766222    39% in    0s    22.95 MB/s
#  15630336 of 35766222    43% in    0s    23.26 MB/s
#  16945152 of 35766222    47% in    0s    23.36 MB/s
#  18255872 of 35766222    51% in    0s    23.44 MB/s
#  19513344 of 35766222    54% in    0s    23.44 MB/s
#  20836352 of 35766222    58% in    0s    23.52 MB/s
#  22204416 of 35766222    62% in    0s    23.64 MB/s
#  23412736 of 35766222    65% in    0s    23.59 MB/s
#  24621056 of 35766222    68% in    0s    23.54 MB/s
#  25681920 of 35766222    71% in    1s    23.45 MB/s
#  26562560 of 35766222    74% in    1s    23.13 MB/s
#  27369472 of 35766222    76% in    1s    22.68 MB/s
#  28790784 of 35766222    80% in    1s    22.85 MB/s
#  30117888 of 35766222    84% in    1s    22.92 MB/s
#  31703040 of 35766222    88% in    1s    23.18 MB/s
#  33263616 of 35766222    93% in    1s    23.41 MB/s
#  34754560 of 35766222    97% in    1s    23.57 MB/s
#  35766222 of 35766222   100% in    1s    23.64 MB/s
#  35766222 of 35766222   100% in    1s    22.42 MB/s  done
